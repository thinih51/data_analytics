# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# (3452, 269)
#    type        id        lat       lon tags.brand tags.brand:wikidata  \
# 0  node  33126515  47.155616  9.037915       Spar             Q610492
# 1  node  36726161  47.226191  8.980329     Migros             Q680727
# 2  node  39768209  47.225154  8.969868       Coop             Q432564
# 3  node  39947904  47.376732  8.542161       Coop             Q432564
# 4  node  48932835  47.375020  8.522895     Migros             Q680727
#
#   tags.brand:wikipedia tags.name  \
# 0   en:SPAR (retailer)      Spar
# 1            de:Migros    Migros
# 2                  NaN      Coop
# 3    de:Coop (Schweiz)      Coop
# 4                  NaN    Migros
#
#                                   tags.opening_hours    tags.shop  ...  \
# 0  Mo-Th 08:00-19:00; Fr 08:00-20:00; Sa 08:00-17:00  supermarket  ...
# 1  Mo-Th 08:00-19:00, Fr 08:00-20:00, Sa 07:30-17...  supermarket  ...
# 2                                                NaN  supermarket  ...
# 3                                  Mo-Sa 06:00-22:00  supermarket  ...
# 4                          Mo-Sa 08:00-21:00; PH off  supermarket  ...
#
#   tags.diet:seafood tags.brand:website tags.recycling:low_energy_bulbs  \
# 0               NaN                NaN                             NaN
# 1               NaN                NaN                             NaN
# 2               NaN                NaN                             NaN
# 3               NaN                NaN                             NaN
# 4               NaN                NaN                             NaN
#
#   tags.image tags.opening_hours:cafe tags.currency:XBT tags.payment:lightning  \
# 0        NaN                     NaN               NaN                    NaN
# 1        NaN                     NaN               NaN                    NaN
# 2        NaN                     NaN               NaN                    NaN
# 3        NaN                     NaN               NaN                    NaN
# 4        NaN                     NaN               NaN                    NaN
#
#   tags.payment:lightning_contactless tags.payment:onchain tags.name:zh-Hans
# 0                                NaN                  NaN               NaN
# 1                                NaN                  NaN               NaN
# 2                                NaN                  NaN               NaN
# 3                                NaN                  NaN               NaN
# 4                                NaN                  NaN               NaN
#
# [5 rows x 269 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.226191  8.980329     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 7  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d635a2b5e40e740f30d928f83783987 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d635a2b5e40e740f30d928f83783987&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d635a2b5e40e740f30d928f83783987 = L.map(
#                 &quot;map_2d635a2b5e40e740f30d928f83783987&quot;,
#                 {
#                     center: [47.007913491737646, 7.9970104281090295],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2d635a2b5e40e740f30d928f83783987);
#
#
#
#
#
#             var tile_layer_39ef638f36a99cfbb90b09429833a2ce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_39ef638f36a99cfbb90b09429833a2ce.addTo(map_2d635a2b5e40e740f30d928f83783987);
#
#
#             var marker_4dd593b4e6a3c00ef457046a3b93873c = L.marker(
#                 [47.2261912, 8.9803292],
#                 {}
#             ).addTo(map_2d635a2b5e40e740f30d928f83783987);
#
#
#         var popup_ba50e04a2334039fb98306626668e569 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_22930af7431a521b9b5400af8bb2acb7 = $(`&lt;div id=&quot;html_22930af7431a521b9b5400af8bb2acb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_ba50e04a2334039fb98306626668e569.setContent(html_22930af7431a521b9b5400af8bb2acb7);
#
#
#
#         marker_4dd593b4e6a3c00ef457046a3b93873c.bindPopup(popup_ba50e04a2334039fb98306626668e569)
#         ;
#
#
#
#
#             var marker_b7540f74067ca19a4275264503093e1c = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_2d635a2b5e40e740f30d928f83783987);
#
#
#         var popup_fdf96e5ba1272fe29bfb3f8988207f7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b60e7ab826c5bf7833509261e2ab8fa = $(`&lt;div id=&quot;html_1b60e7ab826c5bf7833509261e2ab8fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_fdf96e5ba1272fe29bfb3f8988207f7b.setContent(html_1b60e7ab826c5bf7833509261e2ab8fa);
#
#
#
#         marker_b7540f74067ca19a4275264503093e1c.bindPopup(popup_fdf96e5ba1272fe29bfb3f8988207f7b)
#         ;
#
#
#
#
#             var marker_28360b44b56b35e00db758b9feda043b = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_2d635a2b5e40e740f30d928f83783987);
#
#
#         var popup_9e70976dea66b19e55853c496c85a979 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d6966d7b65a1cefeeee758a664ef7ca = $(`&lt;div id=&quot;html_3d6966d7b65a1cefeeee758a664ef7ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_9e70976dea66b19e55853c496c85a979.setContent(html_3d6966d7b65a1cefeeee758a664ef7ca);
#
#
#
#         marker_28360b44b56b35e00db758b9feda043b.bindPopup(popup_9e70976dea66b19e55853c496c85a979)
#         ;
#
#
#
#
#             var marker_8b3bd934edeaa0e82d43f320b0e06e02 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_2d635a2b5e40e740f30d928f83783987);
#
#
#         var popup_6a0303640551eef2b1ce4a90e86fadab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6abde7335cc206aadcf992f35e0bb90d = $(`&lt;div id=&quot;html_6abde7335cc206aadcf992f35e0bb90d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_6a0303640551eef2b1ce4a90e86fadab.setContent(html_6abde7335cc206aadcf992f35e0bb90d);
#
#
#
#         marker_8b3bd934edeaa0e82d43f320b0e06e02.bindPopup(popup_6a0303640551eef2b1ce4a90e86fadab)
#         ;
#
#
#
#
#             var marker_51406bcd44e36b13e2ad26394b3d56eb = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_2d635a2b5e40e740f30d928f83783987);
#
#
#         var popup_a13acfbb7b3c001da35921630faf3295 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8923ceb7d80388fb148442cfe2ca7142 = $(`&lt;div id=&quot;html_8923ceb7d80388fb148442cfe2ca7142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_a13acfbb7b3c001da35921630faf3295.setContent(html_8923ceb7d80388fb148442cfe2ca7142);
#
#
#
#         marker_51406bcd44e36b13e2ad26394b3d56eb.bindPopup(popup_a13acfbb7b3c001da35921630faf3295)
#         ;
#
#
#
#
#             var marker_98b564fd578c6681ccbd0607b775b7e2 = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2025-01-18 08:28:15
# Python Version: 3.11.11
# -----------------------------------
