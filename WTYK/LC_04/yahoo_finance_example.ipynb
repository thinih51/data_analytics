# %% [markdown]
# # Stock market analysis using data from the Yahoo-Finance Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import pandas as pd
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt

# Install additional library yfinance
import yfinance as yf


# Settings
import warnings
warnings.filterwarnings("ignore")

# Current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/WTYK/LC_04

# %% [markdown]
# ## 1.) Get data for the stock TSLA (Tesla) from Yahoo Finance

# %%
# Get current date from datetime in the format YYYY-MM-DD
today = datetime.now().strftime('%Y-%m-%d')

# Retrieve the TESLA stock data from Yahoo finance using yf.download
df = yf.download('TSLA', start = "2022-01-01", end = today, progress=False)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-01-03  382.583344  400.356659  378.679993  399.926666  399.926666
# 2022-01-04  396.516663  402.666656  374.350006  383.196655  383.196655
# 2022-01-05  382.216675  390.113342  360.336670  362.706665  362.706665
# 2022-01-06  359.000000  362.666656  340.166656  354.899994  354.899994
# 2022-01-07  360.123322  360.309998  336.666656  342.320007  342.320007
# ...                ...         ...         ...         ...         ...
# 2024-09-30  259.040009  264.859985  255.770004  261.630005  261.630005
# 2024-10-01  262.670013  263.980011  248.529999  258.019989  258.019989
# 2024-10-02  247.550003  251.160004  241.500000  249.020004  249.020004
# 2024-10-03  244.479996  249.789993  237.809998  240.660004  240.660004
# 2024-10-04  246.690002  250.960007  244.580002  250.080002  250.080002
#
#                Volume
# Date
# 2022-01-03  103931400
# 2022-01-04  100248300
# 2022-01-05   80119800
# 2022-01-06   90336600
# 2022-01-07   84164700
# ...               ...
# 2024-09-30   80705700
# 2024-10-01   87397600
# 2024-10-02   93983900
# 2024-10-03   80729200
# 2024-10-04   86573200
#
# [693 rows x 6 columns]

# %% [markdown]
# ## 2.) Apply non-graphical Exploratory Data Analysis (EDA) methods

# %% [markdown]
# ### a) What are the values for min, max. mean and median of the close price?

# %%
# Describe the dataframe
df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  693.000000  693.000000  693.000000  693.000000  693.000000
# mean   229.547133  234.683156  224.063357  229.331015  229.331015
# std     52.991492   54.073066   51.422470   52.581995   52.581995
# min    103.000000  111.750000  101.809998  108.099998  108.099998
# 25%    186.539993  190.949997  182.550003  187.039993  187.039993
# 50%    226.190002  232.410004  222.020004  227.539993  227.539993
# 75%    260.600006  267.250000  255.300003  261.070007  261.070007
# max    396.516663  402.666656  378.679993  399.926666  399.926666
#
#              Volume
# count  6.930000e+02
# mean   1.074926e+08
# std    3.934795e+07
# min    4.186470e+07
# 25%    7.942880e+07
# 50%    1.006153e+08
# 75%    1.264362e+08
# max    3.065906e+08

# %% [markdown]
# ### b) What is the 10% Quantile and 90% quantile of close price?

# %%
# Calculate quantiles for the dataframe (10% and 90%)
df.quantile([0.1, 0.9])
# Out:
#            Open        High         Low       Close   Adj Close       Volume
# 0.1  170.104007  174.544000  167.198001  170.874002  170.874002   64050600.0
# 0.9  300.594000  307.433325  292.296002  300.475336  300.475336  161045740.0

# %% [markdown]
# ## 3.) Apply graphical Exploratory Data Analysis (EDA) methods

# %% [markdown]
# ### a) Create a line chart of the close price

# %%
# Create a line chart of the close price
plt.figure(figsize=(12, 6))
sns.lineplot(data=df['Close'], label='Close Price')
plt.title('Tesla Stock Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()

# Set the title and axis labels

# Add a legend to the axis

# Add grid

# Show the plot

# %% [markdown]
# ### b) Create a histogram of the close price

# %%
# Create a histogram of the close price
plt.figure(figsize=(12, 6))
sns.histplot(df['Close'], bins=50, color='blue')
plt.title('Tesla Stock Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()


# Plot settings


# Show the plot

# %% [markdown]
# ### c) Create a boxplot of the close price

# %%
# Create a boxplot of the close price
plt.figure(figsize=(10, 2))
sns.boxplot(data=df['Close'], orient="h", color='greenyellow')
plt.title('Tesla Stock Price Distribution')
plt.xlabel('Close Price')
plt.show()


# Show the plot

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-10-07 15:15:39
# Python Version: 3.11.10
# -----------------------------------
